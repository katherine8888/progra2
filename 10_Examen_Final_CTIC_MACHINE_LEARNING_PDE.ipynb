# %% [markdown]
# <a href="https://colab.research.google.com/github/katherine8888/progra2/blob/master/10_Examen_Final_CTIC_MACHINE_LEARNING_PDE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #Tratamiento de datos
import matplotlib.pyplot as plt

# Cargar Data
data = pd.read_csv("reactiva12.csv",sep=';',encoding='latin1')
data.head(10)
# Out:
#    orden                                          rsocial          ruc  \
# 0      1                                 USTA SAGRADA SAC  20553879150
# 1      2                             2L SOLUCIONES S.A.C.  20524693250
# 2      3                            3P INVERSIONES S.A.C.  20551286348
# 3      4                   A & G MISTI CONSTRUCTORESS.A.C  20542311488
# 4      5                            A Y N CALZADOS S.A.C.  20601959217
# 5      6                                 ABRAINO E.I.R.L.  20601644011
# 6      7  AC PROYECTOS GENERALES SOCIEDAD ANONIMA CERRADA  20546964184
# 7      8                              ACERIAS TEFOLCA SAC  20601806461
# 8      9                 ACR IMPORTACIONES GENERALES EIRL  20524657296
# 9     10                               AD MY PLAZA S.A.C.  20603720921
#
#                                      sector                   banco blanco  \
# 0                    HOTELES Y RESTAURANTES  0011 - BANCO BBVA PERU    NaN
# ...

# %%
data.shape
# Out:
# (161371, 9)

# %%
data.describe().transpose()
# Out:
#               count          mean           std     min         25%  \
# orden      161371.0  8.068600e+04  4.658394e+04    1.00     40343.5
# ruc        161371.0  5.792465e+09  8.614653e+09   60.00  27418306.5
# prestamo   161370.0  1.285327e+05  6.593897e+05  234.00      5000.0
# cobertura  161370.0  1.157741e+05  5.594730e+05  229.32      4900.0
#
#                    50%           75%           max
# orden         80686.00  1.210285e+05  1.613710e+05
# ruc        45693973.00  1.044394e+10  2.060587e+10
# prestamo      12611.00  3.300000e+04  1.000000e+07
# cobertura     12358.78  3.234000e+04  8.500000e+06

# %%
# Cargar seaborn 
import seaborn as sns
sns.set(style="whitegrid", color_codes = True)
sns.set(rc={'figure.figsize':(10,6)})
# Analizando el target 
ax = sns.countplot(x='sector', data = data, palette = 'hls',orient="v")
ax.set_xticklabels(ax.get_xticklabels(),rotation = 30)
# Out:
# [Text(0, 0, 'HOTELES Y RESTAURANTES'),
#  Text(0, 0, 'ACTIV. INMOBILIARIAS, EMPRESARIALES ALQ.'),
#  Text(0, 0, 'COMERCIO'),
#  Text(0, 0, 'MINERIA'),
#  Text(0, 0, 'INDUSTRIA MANUFACTURERA'),
#  Text(0, 0, 'PESCA'),
#  Text(0, 0, 'TRANSPORTE, ALMACENAMIENTO Y COMUNIC.'),
#  Text(0, 0, 'AGRICULTUR, GANADERIA, CAZA Y SILVICULT'),
#  Text(0, 0, 'OTROS SERVICIOS'),
#  Text(0, 0, 'CONSTRUCCION'),
#  Text(0, 0, 'SERVICIOS SOCIALES Y DE SALUD'),
#  Text(0, 0, 'INTERMEDIACION FINANCIERA'),
#  Text(0, 0, 'ELECTRICIDAD, GAS Y AGUA'),
#  Text(0, 0, 'ENSENIUANZA'),
#  Text(0, 0, 'ACTIV. INMOBILIARIAS, E')]
